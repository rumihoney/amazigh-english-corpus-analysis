# %%
import os
import kagglehub
import pandas as pd

# %%
path = kagglehub.dataset_download('jasminemohamed2545/berber-english-160k-parallel-sentences-for-nlp')
print(path)
# Out:
# C:\Users\lassa\.cache\kagglehub\datasets\jasminemohamed2545\berber-english-160k-parallel-sentences-for-nlp\versions\1

# %%
pd.read_table('ber.txt')
# Out:
#                                                       Go.  \
# 0                                                     Hi.
# 1                                                     Hi.
# 2                                                     Hi.
# 3                                                     Hi.
# 4                                                     Hi.
# ...                                                   ...
# 160877  One of my favorite quotes by Mark Twain is, "I...
# 160878  If you talk to a man in a language he understa...
# 160879  You can't view Flash content on an iPad. Howev...
# 160880  You can't view Flash content on an iPad. Howev...
# 160881  Doubtless there exists in this world precisely...
#
#                                                      Ṛuḥ.  \
# 0                                                   Azul.
# 1                                           Azul fell-ak.
# 2                                           Azul fell-am.
# 3                                         Azul fell-awen.
# 4                                        Azul fell-awent.
# ...                                                   ...
# 160877  Yiwet seg tnebdurin-inu timenyafin n Mark Twai...
# 160878  Mer ad as-temmeslayeḍ i umdan s tutlayt i ifeh...
# 160879  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160880  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160881  Ulac ccek dakken yal argaz yesɛa tameṭṭut ay t...
#
#        CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)
# 0       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 4       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# ...                                                   ...
# 160877  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 160878  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 160879  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160880  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160881  CC-BY 2.0 (France) Attribution: tatoeba.org #7...
#
# [160882 rows x 3 columns]

# %%
df = pd.read_table('ber.txt')

# %%
df
# Out:
#                                                       Go.  \
# 0                                                     Hi.
# 1                                                     Hi.
# 2                                                     Hi.
# 3                                                     Hi.
# 4                                                     Hi.
# ...                                                   ...
# 160877  One of my favorite quotes by Mark Twain is, "I...
# 160878  If you talk to a man in a language he understa...
# 160879  You can't view Flash content on an iPad. Howev...
# 160880  You can't view Flash content on an iPad. Howev...
# 160881  Doubtless there exists in this world precisely...
#
#                                                      Ṛuḥ.  \
# 0                                                   Azul.
# 1                                           Azul fell-ak.
# 2                                           Azul fell-am.
# 3                                         Azul fell-awen.
# 4                                        Azul fell-awent.
# ...                                                   ...
# 160877  Yiwet seg tnebdurin-inu timenyafin n Mark Twai...
# 160878  Mer ad as-temmeslayeḍ i umdan s tutlayt i ifeh...
# 160879  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160880  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160881  Ulac ccek dakken yal argaz yesɛa tameṭṭut ay t...
#
#        CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)
# 0       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 4       CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# ...                                                   ...
# 160877  CC-BY 2.0 (France) Attribution: tatoeba.org #6...
# 160878  CC-BY 2.0 (France) Attribution: tatoeba.org #2...
# 160879  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160880  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160881  CC-BY 2.0 (France) Attribution: tatoeba.org #7...
#
# [160882 rows x 3 columns]

# %%
df.head(10)
# Out:
#     Go.              Ṛuḥ.  \
# 0   Hi.             Azul.
# 1   Hi.     Azul fell-ak.
# 2   Hi.     Azul fell-am.
# 3   Hi.   Azul fell-awen.
# 4   Hi.  Azul fell-awent.
# 5   Hi.             ⴰⵣⵓⵍ.
# 6   Hi.              azul
# 7  Run!            Azzel!
# 8  Run!              ⴰⵣⵣⵍ
# 9  Run.            Azzel.
#
#   CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)
# 0  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 1  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 2  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 3  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 4  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 5  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 6  CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# 7  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 8  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 9  CC-BY 2.0 (France) Attribution: tatoeba.org #4...

# %%
df.tail(3)
# Out:
#                                                       Go.  \
# 160879  You can't view Flash content on an iPad. Howev...
# 160880  You can't view Flash content on an iPad. Howev...
# 160881  Doubtless there exists in this world precisely...
#
#                                                      Ṛuḥ.  \
# 160879  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160880  Ur tezmired ara ad twalid agbur n Flash deg us...
# 160881  Ulac ccek dakken yal argaz yesɛa tameṭṭut ay t...
#
#        CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)
# 160879  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160880  CC-BY 2.0 (France) Attribution: tatoeba.org #9...
# 160881  CC-BY 2.0 (France) Attribution: tatoeba.org #7...

# %%
df.shape
# Out:
# (160882, 3)

# %%
df.count()
# Out:
# Go.                                                                                160882
# Ṛuḥ.                                                                               160882
# CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)    160882
# dtype: int64

# %%
df.describe()
# Out:
#                  Go.                  Ṛuḥ.  \
# count         160882                160882
# unique         84167                150056
# top     Go home now.  Ur yettett ara waya.
# freq              56                    14
#
#        CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)
# count                                              160882
# unique                                             160882
# top     CC-BY 2.0 (France) Attribution: tatoeba.org #7...
# freq                                                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 160882 entries, 0 to 160881
# Data columns (total 3 columns):
#  #   Column                                                                           Non-Null Count   Dtype
# ---  ------                                                                           --------------   -----
#  0   Go.                                                                              160882 non-null  object
#  1   Ṛuḥ.                                                                             160882 non-null  object
#  2   CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #8325200 (Yagurten)  160882 non-null  object
# dtypes: object(3)
# memory usage: 3.7+ MB
